# %%
import cv2
import numpy as np
import os
from random import shuffle

img_bgr = cv2.imread("/content/drive/MyDrive/data50/train/cats/cat.1.jpg", 1)

print(type(img_bgr))
print(img_bgr.shape)
# Out:
# <class 'numpy.ndarray'>
# (280, 300, 3)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
plt.imshow(img_bgr)

# %%
import matplotlib.pyplot as plt

im_rgb  = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(4,4))
plt.imshow(im_rgb)

# %%
import cv2
import numpy as np
import os
from random import shuffle
from tqdm import tqdm

folder1 = '/content/drive/MyDrive/data50/train/cats'
folder2 = '/content/drive/MyDrive/data50/train/dogs'

folder3  = '/content/drive/MyDrive/data50/validation/cats'
folder4  = '/content/drive/MyDrive/data50/validation/dogs'

IMG_SIZE  = 50

def get_label(image_name):
    word_label = image_name.split('.')[0]

    if word_label == 'cat':
        return 0
    elif word_label == 'dog':
        return 1


# training data
X_train = []
y_train = []

for img_name in tqdm(os.listdir(folder1)):
    label = get_label(img_name)
    path  = os.path.join(folder1, img_name)

    img = cv2.imread(path, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

    X_train.append(img)
    y_train.append(label)

for img_name in tqdm(os.listdir(folder2)):
    label = get_label(img_name)
    path  = os.path.join(folder2, img_name)

    img = cv2.imread(path, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

    X_train.append(img)
    y_train.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)

#np.save('cats_and_dog/X_train.npy', X_train)
#np.save('cats_and_dog/y_train.npy', y_train)


# ----------------------------------------------
X_test = []
y_test = []

for img_name in tqdm(os.listdir(folder3)):
    label = get_label(img_name)
    path  = os.path.join(folder3, img_name)

    img = cv2.imread(path, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

    X_test.append(img)
    y_test.append(label)

for img_name in tqdm(os.listdir(folder4)):
    label = get_label(img_name)
    path  = os.path.join(folder4, img_name)

    img = cv2.imread(path, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

    X_test.append(img)
    y_test.append(label)

X_test  = np.array(X_test)
y_test = np.array(y_test)

#np.save('cats_and_dog/X_test.npy', X_test)
#np.save('cats_and_dog/y_test.npy', y_test)

print(X_test.shape)
print(y_test.shape)
# Out:
# ...
# 100%|██████████| 500/500 [00:06<00:00, 75.30it/s]
# (1004, 50, 50, 3)
# (1004,)
